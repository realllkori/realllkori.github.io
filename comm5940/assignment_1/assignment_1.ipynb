# %% [markdown]
# <h1>MySQL and Airtable Data Access</h1>

# %%
# !pip install PyMySQL

# %%
import pymysql.cursors
connection = pymysql.connect(host="localhost", 
                     user="root",   
                     passwd="root", 
                     db="assignment_1",   
                     charset='utf8mb4',
                     cursorclass=pymysql.cursors.DictCursor)

# %%
with connection.cursor() as cursor:
        sql = "SELECT * FROM `TABLE 1`"
        cursor.execute(sql)
        result = cursor.fetchall()
        dataset = []
        temp = {}
        i = 0
        for row in result:
            temp[i] = row
            dataset.append(temp[i])
            i = i + 1
        print('\n')
        print(dataset)
        print('\n')
# Out:
# [{'COL 1': '狗隻種類', 'COL 2': '體型', 'COL 3': '功能', 'COL 4': '特點', 'COL 5': ''}, {'COL 1': '哈士奇', 'COL 2': '中型', 'COL 3': '工作犬', 'COL 4': '友善', 'COL 5': ''}, {'COL 1': '藏獒', 'COL 2': '大型', 'COL 3': '工作犬', 'COL 4': '不掉毛,不愛叫', 'COL 5': ''}, {'COL 1': '澳大利亞牧牛犬', 'COL 2': '中型', 'COL 3': '牧羊犬', 'COL 4': '聰明,易訓練', 'COL 5': ''}, {'COL 1': '秋田犬', 'COL 2': '超大型', 'COL 3': '工作犬', 'COL 4': '不愛叫,會看家', 'COL 5': ''}, {'COL 1': '凱利藍梗', 'COL 2': '中型', 'COL 3': '梗類犬', 'COL 4': '不掉毛,不愛叫', 'COL 5': ''}, {'COL 1': '西帕基犬', 'COL 2': '小型', 'COL 3': '家庭犬', 'COL 4': '聰明', 'COL 5': ''}, {'COL 1': '冰島牧羊犬', 'COL 2': '中型', 'COL 3': '牧羊犬', 'COL 4': '友善', 'COL 5': ''}, {'COL 1': '切薩皮克海灣尋回犬', 'COL 2': '大型', 'COL 3': '槍獵犬', 'COL 4': '不愛叫,友善,耐熱,易訓練', 'COL 5': ''}, {'COL 1': '臘腸犬', 'COL 2': '中型', 'COL 3': '狩獵犬', 'COL 4': '會看家', 'COL 5': ''}, {'COL 1': '馬士提夫獒犬', 'COL 2': '超大型', 'COL 3': '工作犬', 'COL 4': '不愛叫', 'COL 5': ''}, {'COL 1': '阿拉斯加雪橇犬', 'COL 2': '大型', 'COL 3': '工作犬', 'COL 4': '不愛叫', 'COL 5': ''}, {'COL 1': '小型鬥牛梗',
# ...

# %%
import requests

headers = {
'Authorization': 'Bearer keybXfluNBh6MO4fz',
}

params = (
('view', 'Grid view'),
)

r = requests.get('https://api.airtable.com/v0/appJWWovfxpfQ27J5/dog_type?api_key=keybXfluNBh6MO4fz&sortField=_createdTime&sortDirection=desc', headers=headers, params=params)
dict = r.json()
dataset = []
dog_type = []
size = []
specialty = []
for i in dict['records']:
     dict = i['fields']
     dataset.append(dict)
print(dataset)
print('\n')
for dicts in dataset:
    dog_type.append(dicts.get('dog_type'))
    size.append(dicts.get('size'))
    specialty.append(dicts.get('specialty'))
print(dog_type)
# Out:
# [{'dog_type': '迷你貝吉格裡芬凡丁犬', '圖片': [{'id': 'attuZk0cof9dFiemL', 'url': 'https://dl.airtable.com/.attachments/7305fb127bfbc95b4752699c3f5e7761/8e659456/u1923371332990962128fm5', 'filename': 'u=1923371332,990962128&fm=5', 'size': 9556, 'type': 'image/jpeg', 'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/49980eabcfead24dde5bcb2c4828c944/870ce946', 'width': 36, 'height': 36}, 'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/3754dfb029a551e17c55a73e7ac25203/98f50687', 'width': 121, 'height': 121}, 'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/13712ef06c27cb77d308e38a6a7cd3d0/2e13e5e0', 'width': 3000, 'height': 3000}}}], 'size': '小型', 'function': ['狩獵犬'], 'specialty': ['粘人', '不掉毛', '友善']}, {'dog_type': '義大利灰狗', '圖片': [{'id': 'attiUT3cLG0lsZtiI', 'url': 'https://dl.airtable.com/.attachments/f5bc3ec33ffa82f25e28f3e341b55ced/69a41b2d/u2009379220550263340fm5', 'filename': 'u=2009379220,550263340&fm=5', 'size': 6808, 'type': 'image/
# ...
